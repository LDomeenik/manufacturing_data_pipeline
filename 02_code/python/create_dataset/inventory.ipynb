# %%
# 데이터 로드
import pandas as pd

df = pd.read_csv("supply_chain_data.csv")

df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
# 3                59  ...   Kolkata        24                 937
# 4                56  ...     Delhi         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
# [5 rows x 24 columns]

# %%
# 필요 컬럼
df = df[[
    "SKU",
    "Price",
    "Stock levels",
    "Order quantities",
    "Lead time",
    "Manufacturing costs"
]]

df.head()
# Out:
#     SKU      Price  Stock levels  Order quantities  Lead time  \
# 0  SKU0  69.808006            58                96         29
# 1  SKU1  14.843523            53                37         23
# 2  SKU2  11.319683             1                88         12
# 3  SKU3  61.163343            23                59         24
# 4  SKU4   4.805496             5                56          5
#
#    Manufacturing costs
# 0            46.279879
# 1            33.616769
# 2            30.688019
# 3            35.624741
# 4            92.065161

# %%
# 기본 QC -> 이상 없음
print("PK/FK 컬럼 중복 확인(SKU):", df["SKU"].nunique(), len(df))
print("원재고 음수 값:", (df["Stock levels"] < 0).sum())
# Out:
# PK/FK 컬럼 중복 확인(SKU): 100 100
# 원재고 음수 값: 0

# %%
# 컬럼명 변경
df = df.rename(columns={
    "SKU" : "material_id",
    "Product type" : "material_type",
    "Price" : "unit_price",
    "Stock levels" : "stock_qty",
    "Order quantities" : "incoming_qty",
    "Lead time" : "lead_time",
    "Manufacturing costs" : "manufacturing_cost"
})

df.head()
# Out:
#   material_id  unit_price  stock_qty  incoming_qty  lead_time  \
# 0        SKU0   69.808006         58            96         29
# 1        SKU1   14.843523         53            37         23
# 2        SKU2   11.319683          1            88         12
# 3        SKU3   61.163343         23            59         24
# 4        SKU4    4.805496          5            56          5
#
#    manufacturing_cost
# 0           46.279879
# 1           33.616769
# 2           30.688019
# 3           35.624741
# 4           92.065161

# %%
# PK 타입 정리
df["material_id"] = df["material_id"].astype(str)

# %%
# CSV로 내보내기
try:
    df.to_csv("inventory.csv", index=False)
    print("inventory.csv 생성 완료:", df.shape)
    
except Exception as e:
    print("생성 실패:", e)
# Out:
# inventory.csv 생성 완료: (100, 6)
